# %%
# !git clone https://github.com/mikolaura/paligemma.git

# !pip install fire numpy pillow safetensors tokenizers transformers
# Out:
# Cloning into 'paligemma'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 76 (delta 28), reused 62 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (76/76), 232.44 KiB | 5.81 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114248 sha256=adc7d3a4bf2807b730844146b01d36321d76dcb4f57ee4a30ff954d410b08793
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built fire
# ...

# %%
# !pip install "huggingface_hub[hf_transfer]"

# !$HF_HUB_ENABLE_HF_TRANSFER=1
# Out:
# ...
# WARNING: huggingface-hub 0.25.1 does not provide the extra 'hf-transfer'
# ...
# /bin/bash: line 1: =1: command not found

# %%
from huggingface_hub.hf_api import HfFolder
HfFolder.save_token('YOUR TOKEN  HERE')

# %%
# !mkdir pali
# Out:
# mkdir: cannot create directory 'pali': File exists

# %%
# !huggingface-cli download google/paligemma-3b-pt-224 --local-dir pali
# Out:
# Fetching 14 files:   0%|                                 | 0/14 [00:00<?, ?it/s]Downloading 'config.json' to 'pali/.cache/huggingface/download/config.json.b89393ba09b432265173f688b8a41a2c3c9e3e4c.incomplete'
# ...
#
# config.json: 100%|█████████████████████████| 1.03k/1.03k [00:00<00:00, 5.70MB/s]
# Download complete. Moving file to pali/config.json
# ...
#
# generation_config.json: 100%|███████████████████| 137/137 [00:00<00:00, 972kB/s]
# Download complete. Moving file to pali/generation_config.json
# ...
#
# added_tokens.json: 100%|██████████████████████| 24.0/24.0 [00:00<00:00, 164kB/s]
# Download complete. Moving file to pali/added_tokens.json
# ...
#
# .gitattributes: 100%|██████████████████████| 1.57k/1.57k [00:00<00:00, 10.2MB/s]
# Download complete. Moving file to pali/.gitattributes
# ...
# Fetching 14 files:   7%|█▊                       | 1/14 [00:00<00:02,  5.04it/s]
# model-00003-of-00003.safetensors:   0%|             | 0.00/1.74G [00:00<?, ?B/s]
#
# ...

# %%
# !python paligemma/inference.py --model_path ""pali"" --prompt "On what the person on image is sitting" --image_file_path "paligemma/test_images/pic3.jpg" --max_tokens_to_generate 15 --temperature 0.8 --top_p 0.9 --do_sample "False" --only_cpu "False"
# Out:
# Device in use:  cuda
# Loading model
# {'_name_or_path': 'final-hf/paligemma-3b-pt-224-main', 'architectures': ['PaliGemmaForConditionalGeneration'], 'bos_token_id': 2, 'eos_token_id': 1, 'hidden_size': 2048, 'ignore_index': -100, 'image_token_index': 257152, 'model_type': 'paligemma', 'pad_token_id': 0, 'projection_dim': 2048, 'text_config': {'hidden_size': 2048, 'intermediate_size': 16384, 'model_type': 'gemma', 'num_attention_heads': 8, 'num_hidden_layers': 18, 'num_image_tokens': 256, 'num_key_value_heads': 1, 'torch_dtype': 'float32', 'vocab_size': 257216}, 'torch_dtype': 'float32', 'transformers_version': '4.41.0.dev0', 'vision_config': {'hidden_size': 1152, 'intermediate_size': 4304, 'model_type': 'siglip_vision_model', 'num_attention_heads': 16, 'num_hidden_layers': 27, 'num_image_tokens': 256, 'patch_size': 14, 'projection_dim': 2048, 'projector_hidden_act': 'gelu_fast', 'vision_use_head': False}, 'vocab_size': 257216}
# Model created
# Running inference
# ...
